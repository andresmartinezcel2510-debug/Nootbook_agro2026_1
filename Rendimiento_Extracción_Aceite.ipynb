# %% [markdown]
# <a href="https://colab.research.google.com/github/andresmartinezcel2510-debug/Nootbook_agro2026_1/blob/main/Rendimiento_Extracci%C3%B3n_Aceite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Andres Eduardo Martinez Arrieta (1104259062)
Cristian David Arrieta payares )1102819197)

# %% [markdown]
# **Control de Rendimiento en Extracción de Aceite**
#
# Este ejercicio es ideal para introducir float, int y la concatenación de strings.
#
# **Planteamiento:**
#
# Una planta procesadora de palma de aceite necesita calcular el **Índice de Rendimiento de Extracción (IRE)**. El operario debe ingresar el peso total de los racimos de fruta fresca (RFF) procesados en kilogramos y la cantidad de aceite crudo obtenido en litros.
#
# **Requerimientos:**
#
# 1. Solicitar el nombre del lote de producción (Tipo string).
# 2. Solicitar el peso de los racimos en kg (Tipo float). (pr)
# 3. Solicitar los litros de aceite obtenidos (Tipo float). (lt)
# 4. Calcular el rendimiento sabiendo que la densidad aproximada del aceite es de 0.92 kg/L. (r)
# .
# $$pa = lt * 0.92$$
#
# $$r =(pa/pr)*100$$
#
# **Prueba del programa:**
#
# Si se ingresan **1000 kg** de racimos y se obtienen **200** litros de aceite, el programa debe informar que el rendimiento del lote es del **18.4%**.

# %%
# ENTRADA: Solicitar el nombre del lote de producción (Tipo string).
# Solicitar el peso de los racimos en kg (Tipo float). (pr)
# Solicitar los litros de aceite obtenidos (Tipo float). (lt)
nombre=input("Ingrese el nombre del lote: ")
pr=float(input("Ingrese el peso de los racimos en kg: "))
lt=float(input("Ingrese los litros de aceite obtenidos: "))


# PROCESO: calcular peso del aceite (pa) y el rendimiento (r)
pa=lt*0.92
r=(pa/pr)*100


# SALIDA: Informar el rendimiento del lote
print("El rendimiento del lote",nombre,"es del",r,"%")
# Out:
# Ingrese el nombre del lote: el perico
# Ingrese el peso de los racimos en kg: 1000
# Ingrese los litros de aceite obtenidos: 200
# El rendimiento del lote el perico es del 18.4 %

# %% [markdown]
# ```markdown
# Aquí está la explicación de cada línea del código para el problema de 'Control de Rendimiento en Extracción de Aceite':
#
# ```python
# # ENTRADA: Solicitar el nombre del lote de producción (Tipo string).
# # Solicitar el peso de los racimos en kg (Tipo float). (pr)
# # Solicitar los litros de aceite obtenidos (Tipo float). (lt)
# ```
# Estas líneas con `#` son comentarios. Los comentarios son textos que los programadores añaden al código para explicar lo que hace una parte del programa. Python ignora los comentarios al ejecutar el código.
#
# ```python
# nombre=input("Ingrese el nombre del lote: ")
# ```
# Esta línea utiliza la función `input()` para pedir al usuario que ingrese el nombre del lote de producción. El texto entre comillas `"Ingrese el nombre del lote: "` es el mensaje que se mostrará al usuario. Lo que el usuario escriba se guardará como una cadena de texto (string) en la variable llamada `nombre`.
#
# ```python
# pr=float(input("Ingrese el peso de los racimos en kg: "))
# ```
# De manera similar a la línea anterior, esta línea pide al usuario que ingrese el peso de los racimos. Sin embargo, lo que el usuario ingresa se pasa a la función `float()`. La función `float()` convierte el texto ingresado en un número decimal (de tipo 'float'). Este valor numérico se guarda en la variable `pr` (peso de los racimos).
#
# ```python
# lt=float(input("Ingrese los litros de aceite obtenidos: "))
# ```
# Esta línea es igual a la anterior, pero solicita la cantidad de litros de aceite obtenidos. El valor ingresado por el usuario se convierte a un número decimal (`float`) y se guarda en la variable `lt` (litros de aceite).
#
# ```python
# # PROCESO: calcular peso del aceite (pa) y el rendimiento (r)
# ```
# Otro comentario que indica que las siguientes líneas realizan los cálculos necesarios.
#
# ```python
# pa=lt*0.92
# ```
# Aquí se calcula el peso del aceite (`pa`). Se multiplica la cantidad de litros de aceite (`lt`) por su densidad aproximada, que es `0.92` kg/L. El resultado se almacena en la variable `pa` (peso del aceite).
#
# ```python
# r=(pa/pr)*100
# ```
# Esta línea calcula el Índice de Rendimiento de Extracción (`r`). Se divide el peso del aceite (`pa`) entre el peso de los racimos (`pr`) y luego se multiplica por `100` para obtener el porcentaje. El resultado se guarda en la variable `r`.
#
# ```python
# # SALIDA: Informar el rendimiento del lote
# ```
# Un comentario que señala que la siguiente línea mostrará el resultado al usuario.
#
# ```python
# print("El rendimiento del lote",nombre,"es del",r,"%")
# ```
# Finalmente, esta línea utiliza la función `print()` para mostrar el resultado al usuario. Concatena varias cadenas de texto y los valores de las variables `nombre` y `r` para formar un mensaje legible que informa el rendimiento del lote.
